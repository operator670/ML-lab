# %%
def get_squared_distance(point1, point2):
    return round((point2[0] - point1[0])**2 -(point2[1] - point1[1])**2 ,4)

# %%
def getDistanceFromPoints(centroids, datapoints):
    distance_from_cluster = []
    intermediate_result = []
    for i in centroids:
        for j in datapoints:
            intermediate_result.append(get_squared_distance(i,j))
        distance_from_cluster.append(intermediate_result)
        intermediate_result = []
    return distance_from_cluster

# %%
def printResult(centroids,point_to_cluster_mapping):
    for i in range(len(centroids)):
        print("Centroid",i, centroids[i])
    for i in point_to_cluster_mapping:
        print("Point: ", i , "Cluster:", point_to_cluster_mapping[i])

# %%
def kmeansclustering(centroids, datapoints):
    k = len(centroids)
    distance_from_cluster = getDistanceFromPoints(centroids, datapoints) # [cluster1_distances, cluster2_distances,...]
    
    
    # assign each datapoint to the nearest cluster
    
    point_to_cluster_mapping = {}   # point -> cluster
    max_valued_cluster = 0
    for i in range(len(datapoints)):
        point_to_cluster_mapping[i] = None  # initial mapping as None
        for cluster in range(len(centroids)):
            if distance_from_cluster[cluster][i] < distance_from_cluster[max_valued_cluster][i]:
                max_valued_cluster = cluster
        point_to_cluster_mapping[i] = max_valued_cluster
    
    # compute new centroids by averaging with new points
    cluster_counter = 0       # [cluster1_new_elements_added, cluster2_new_elements_added...]
    for i in range(len(centroids)):
        for j in point_to_cluster_mapping:
            if point_to_cluster_mapping[j] == i:
                centroids[i][0] += datapoints[j][0]   # x-coordinate adding
                centroids[i][1] += datapoints[j][1]   # y-coordinate adding
                cluster_counter += 1
        if cluster_counter != 0:
            centroids[i][0] = round(centroids[i][0]/cluster_counter,4)
            centroids[i][1] = round(centroids[i][1]/cluster_counter,4)
            cluster_counter = 0
        
    printResult(centroids, point_to_cluster_mapping)
    return centroids

# %%
def kmeans_iterator(centroids,datapoints):
    old_centroids = centroids
    new_centroids = centroids
    iteration = 0
    
    while iteration != 15:
        iteration+=1
        print("\nIteration",iteration)
        old_centroids = new_centroids
        new_centroids = kmeansclustering(new_centroids,datapoints)
        
centroids = [[2,10], [5,8], [1,2]]
datapoints = [[2,10], [2,5], [8,4], [5,8], [7,5], [6,4], [1,2], [4,9]]

# %%
kmeans_iterator(centroids, datapoints)
# Out:
# Iteration 1
# Centroid 0 [3.6667, 7.0]
# Centroid 1 [10.0, 8.5]
# Centroid 2 [4.0, 9.6667]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 1
# Point:  3 Cluster: 2
# Point:  4 Cluster: 1
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 2
#
# Iteration 2
# Centroid 0 [4.8334, 13.0]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.0, 6.7333]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 1
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 0
#
# Iteration 3
# Centroid 0 [5.4048, 7.1429]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [7.0, 16.7333]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 0
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 0
#
# Iteration 4
# Centroid 0 [5.4048, 7.1429]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.25, 7.9667]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 2
#
# Iteration 5
# Centroid 0 [5.4683, 11.381]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.85, 5.5933]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 0
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 0
#
# Iteration 6
# Centroid 0 [5.7447, 6.5635]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.925, 12.2966]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 0
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 2
#
# Iteration 7
# Centroid 0 [7.7447, 16.5635]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.5607, 7.0424]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 2
#
# Iteration 8
# Centroid 0 [5.3431, 7.9454]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.5607, 7.0424]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 0
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 0
#
# Iteration 9
# Centroid 0 [5.8686, 5.5891]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.5202, 11.3475]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 2
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 2
#
# Iteration 10
# Centroid 0 [5.9343, 12.2946]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.7534, 6.5579]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 0
#
# Iteration 11
# Centroid 0 [5.562, 7.0421]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [7.7534, 16.5579]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 0
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 0
#
# Iteration 12
# Centroid 0 [5.562, 7.0421]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.3442, 7.9447]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 2
#
# Iteration 13
# Centroid 0 [5.5207, 11.3474]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.8688, 5.5889]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 0
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 0
#
# Iteration 14
# Centroid 0 [5.7534, 6.5579]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.9344, 12.2944]
# Point:  0 Cluster: 2
# Point:  1 Cluster: 0
# Point:  2 Cluster: 0
# Point:  3 Cluster: 0
# Point:  4 Cluster: 0
# Point:  5 Cluster: 0
# Point:  6 Cluster: 0
# Point:  7 Cluster: 2
#
# Iteration 15
# Centroid 0 [7.7534, 16.5579]
# Centroid 1 [18.0, 12.5]
# Centroid 2 [5.5621, 7.0421]
# Point:  0 Cluster: 0
# Point:  1 Cluster: 2
# Point:  2 Cluster: 2
# Point:  3 Cluster: 2
# Point:  4 Cluster: 2
# Point:  5 Cluster: 2
# Point:  6 Cluster: 2
# Point:  7 Cluster: 2
